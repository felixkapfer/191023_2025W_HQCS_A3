# %%
import pennylane as qml
from pennylane import numpy as np
from pennylane.optimize import NesterovMomentumOptimizer
import math

import pandas as pd
import numpy as np
import pennylane as qml
from pennylane import numpy as qnp
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# First we load the datasets:

# %%
gluehwein = 'gluehweindorf'
krampus = 'krampuskogel'
lebkuchen = 'lebkuchenstadt'

villages = [gluehwein, krampus, lebkuchen]
datasets = {}

for village in villages:
        datasets[village] = pd.read_csv(f'{village}.csv')

# %% [markdown]
# There are no null values in the dataset and 500 entries

# %%
datasets[gluehwein].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   carol_singing    500 non-null    float64
#  1   snowball_energy  500 non-null    float64
#  2   label            500 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 11.8 KB

# %%
datasets[krampus].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   carol_singing    500 non-null    float64
#  1   snowball_energy  500 non-null    float64
#  2   label            500 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 11.8 KB

# %%
datasets[lebkuchen].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   carol_singing    500 non-null    float64
#  1   snowball_energy  500 non-null    float64
#  2   label            500 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 11.8 KB

# %% [markdown]
# Min-Max values

# %%
for name in (gluehwein, krampus, lebkuchen):
    print(f'{name}-carol_singing: min: {datasets[name]['carol_singing'].min()}, max: {datasets[name]['carol_singing'].max()}')
    print(f'{name}-snowball_energy: min: {datasets[name]['snowball_energy'].min()}, max: {datasets[name]['snowball_energy'].max()}')
    print()
# Out:
# gluehweindorf-carol_singing: min: -2.9804047381428838, max: 2.9371221242497527
# gluehweindorf-snowball_energy: min: -2.9723258785728337, max: 3.141592653589793
#
# krampuskogel-carol_singing: min: -3.141592653589793, max: 3.117552213512825
# krampuskogel-snowball_energy: min: -2.8957902158960995, max: 2.8898416183940667
#
# lebkuchenstadt-carol_singing: min: -1.620977694446723, max: 3.141592653589793
# lebkuchenstadt-snowball_energy: min: -0.6755685974503365, max: 1.4214525718679278

# %% [markdown]
# Label values

# %%
for name in (gluehwein, krampus, lebkuchen):
    print(f'{name}-labels:  {datasets[gluehwein]['label'].unique()}')
# Out:
# gluehweindorf-labels:  [1 0]
# krampuskogel-labels:  [1 0]
# lebkuchenstadt-labels:  [1 0]

# %%
X_train = {}
y_train = {}

for name in (gluehwein, krampus, lebkuchen):
    X_train[name] = datasets[name][['carol_singing', 'snowball_energy']].values
    y_train[name] = datasets[name]['label'].values

# %% [markdown]
# # Encoding

# %% [markdown]
# ## Amplitude encoding

# %%
def amplitude_encoding(inputs, wires):
    qml.AmplitudeEmbedding(
        features=inputs,
        wires=wires,
        normalize=True,
        pad_with=0.0
    )

# %% [markdown]
# ## Angle encoding

# %%
def angle_encoding(inputs, wires):
    qml.AngleEmbedding(
        features=inputs, 
        wires=wires, 
        rotation='Y')

# %% [markdown]
# ## Density matrix encoding

# %%
def density_matrix_encoding(inputs, wires):    
    x0, x1 = inputs
    rho = np.outer(inputs, inputs) / np.inner(inputs, inputs)

    qml.QubitDensityMatrix(rho, wires=wires)

# %% [markdown]
# # Entanglement

# %% [markdown]
# ## Linear Entanglement

# %%
def linear_entanglement(wires):
    for i in range(len(wires) - 1):
        qml.CNOT(wires=[wires[i], wires[i + 1]])

# %% [markdown]
# ## Circular Entanglement

# %%
def circular_entanglement(wires):
    linear_entanglement(wires)
    qml.CNOT(wires=[wires[-1], wires[0]])

# %% [markdown]
# ## Full Entanglement

# %%
def full_entanglement(wires):
    for i in range(len(wires)):
        for j in range(i + 1, len(wires)):
            qml.CNOT(wires=[wires[i], wires[j]])

# %% [markdown]
# # QML Circuit

# %%
def make_qml_circuit(dev):
    
    @qml.qnode(dev)
    def qml_circuit(weights, inputs, encoding_fn, entanglement_fn, reuploading_count):
        encoding_fn(inputs, wires=list(range(num_qubits)))

        for j in range(reuploading_count):
            entanglement_fn(wires=list(range(num_qubits)))
            for i in range(num_qubits):
                qml.RY(weights[j][i], wires=i)

        return qml.expval(qml.PauliZ(0)) # this returns a number between the eigenvalues of Z, which are -1 and 1
    
    return qml_circuit

# %% [markdown]
# # Cost

# %%
def cost(weights, param):
    [X, Y, qml_circuit, encoding_fn, entanglement_fn, reuploading_count] = param
    predictions = qnp.array([
        (qml_circuit(weights, x, encoding_fn, entanglement_fn, reuploading_count) * 0.5 + 1)
        for x in X
    ])
    return qnp.mean((predictions - Y) ** 2)

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## Gluehweindorf

# %%
opt = qml.AdamOptimizer(stepsize=0.01)

num_qubits = 2
dev = qml.device("default.qubit", wires=num_qubits)
qml_circuit = make_qml_circuit(dev)

encoding_fn = amplitude_encoding
entanglement_fn = linear_entanglement 

X = X_train[gluehwein]
Y = y_train[gluehwein]


for reuploading_count in (1, 3):
    weights = qnp.array(
        np.random.uniform(0, math.pi, size=(reuploading_count, num_qubits)), 
        requires_grad=True
    )
    
    param = [X, Y, qml_circuit, encoding_fn, entanglement_fn, reuploading_count]

    for epoch in range(100):
        args, current_cost = opt.step_and_cost(cost, weights, param)
        weights = args[0]
        if epoch % 10 == 0 or epoch == 99: 
            print(f"Epoch {epoch + 1}: Cost = {current_cost:.4f} Weights = {weights}")
# Out:
# Epoch 1: Cost = 0.2500 Weights = [[3.13823507 0.91877414]]
# Epoch 11: Cost = 0.2500 Weights = [[3.1386148  0.91877414]]
# Epoch 21: Cost = 0.2500 Weights = [[3.14092443 0.91877414]]
# Epoch 31: Cost = 0.2500 Weights = [[3.1451947  0.91877414]]
# Epoch 41: Cost = 0.2500 Weights = [[3.14171614 0.91877414]]
# Epoch 51: Cost = 0.2500 Weights = [[3.14008412 0.91877414]]
# Epoch 61: Cost = 0.2500 Weights = [[3.14021617 0.91877414]]
# Epoch 71: Cost = 0.2500 Weights = [[3.14089155 0.91877414]]
# Epoch 81: Cost = 0.2500 Weights = [[3.1412679  0.91877414]]
# Epoch 91: Cost = 0.2500 Weights = [[3.14142317 0.91877414]]
# Epoch 100: Cost = 0.2500 Weights = [[3.14147944 0.91877414]]
# Epoch 1: Cost = 0.6144 Weights = [[1.98426147 2.78941061]
#  [0.08488078 2.16226564]
#  [0.9643636  1.91529362]]
# Epoch 11: Cost = 0.4651 Weights = [[ 2.13561616  2.90586482]
#  [-0.03946384  2.01217803]
#  [ 0.81319574  1.91529362]]
# Epoch 21: Cost = 0.3478 Weights = [[2.29807148 2.85993045]
#  [0.01384231 1.85785385]
#  [0.65236557 1.91529362]]
# Epoch 31: Cost = 0.2937 Weights = [[2.42822716e+00 2.89495182e+00]
#  [9.15568336e-04 1.74395475e+00]
#  [5.26422345e-01 1.91529362e+00]]
# Epoch 41: Cost = 0.2720 Weights = [[ 2.52213666e+00  2.91589201e+00]
#  [-2.15066318e-03  1.67025564e+00]
#  [ 4.38801089e-01  1.91529362e+00]]
# Epoch 51: Cost = 0.2627 Weights = [[2.58808198 2.92526054]
#  [0.01098973 1.62454936]
#  [0.37999707 1.91529362]]
# Epoch 61: Cost = 0.2583 Weights = [[2.63551839 2.98239937]
#  [0.00422996 1.59567281]
#  [0.33969023 1.91529362]]
# Epoch 71: Cost = 0.2559 Weights = [[2.67136487 3.03103072]
#  [0.0057911  1.57641694]
#  [0.31056593 1.91529362]]
# Epoch 81: Cost = 0.2545 Weights = [[2.69996207 3.08251823]
#  [0.00973636 1.56268222]
#  [0.2881906  1.91529362]]
# Epoch 91: Cost = 0.2535 Weights = [[2.7238636  3.14831922]
#  [0.00952677 1.55224594]
#  [0.27003616 1.91529362]]
# Epoch 100: Cost = 0.2529 Weights = [[2.74259515 3.20926529]
#  [0.00996339 1.54466887]
#  [0.25611367 1.91529362]]

# %% [markdown]
# ## Krampus

# %%
opt = qml.AdamOptimizer(stepsize=0.01)

num_qubits = 2
dev = qml.device("default.qubit", wires=num_qubits)
qml_circuit = make_qml_circuit(dev)

encoding_fn = angle_encoding
entanglement_fn = circular_entanglement 

X = X_train[krampus]
Y = y_train[krampus]


for reuploading_count in (1, 3):
    weights = qnp.array(
        np.random.uniform(0, math.pi, size=(reuploading_count, num_qubits)), 
        requires_grad=True
    )
    
    param = [X, Y, qml_circuit, encoding_fn, entanglement_fn, reuploading_count]

    for epoch in range(100):
        args, current_cost = opt.step_and_cost(cost, weights, param)
        weights = args[0]
        if epoch % 10 == 0 or epoch == 99: 
            print(f"Epoch {epoch + 1}: Cost = {current_cost:.4f} Weights = {weights}")
# Out:
# Epoch 1: Cost = 0.4577 Weights = [[2.27239813 2.5172095 ]]
# Epoch 11: Cost = 0.4498 Weights = [[2.37158926 2.5172095 ]]
# Epoch 21: Cost = 0.4435 Weights = [[2.46713114 2.5172095 ]]
# Epoch 31: Cost = 0.4387 Weights = [[2.55656896 2.5172095 ]]
# Epoch 41: Cost = 0.4351 Weights = [[2.63863777 2.5172095 ]]
# Epoch 51: Cost = 0.4323 Weights = [[2.7131636 2.5172095]]
# Epoch 61: Cost = 0.4302 Weights = [[2.78064945 2.5172095 ]]
# Epoch 71: Cost = 0.4286 Weights = [[2.84186859 2.5172095 ]]
# Epoch 81: Cost = 0.4274 Weights = [[2.89760097 2.5172095 ]]
# Epoch 91: Cost = 0.4265 Weights = [[2.94850665 2.5172095 ]]
# Epoch 100: Cost = 0.4258 Weights = [[2.99061238 2.5172095 ]]
# Epoch 1: Cost = 0.6953 Weights = [[0.44609773 0.35005176]
#  [2.96703133 0.4990649 ]
#  [0.3884364  2.82283908]]
# Epoch 11: Cost = 0.6187 Weights = [[0.59328101 0.50242029]
#  [2.88814448 0.65139856]
#  [0.4569901  2.82283908]]
# Epoch 21: Cost = 0.5361 Weights = [[0.75626224 0.66180965]
#  [2.74904957 0.82085765]
#  [0.5233128  2.82283908]]
# Epoch 31: Cost = 0.4846 Weights = [[0.89346435 0.75249193]
#  [2.61173262 0.9656651 ]
#  [0.57049621 2.82283908]]
# Epoch 41: Cost = 0.4569 Weights = [[0.99804872 0.75028784]
#  [2.49329746 1.07669821]
#  [0.59959073 2.82283908]]
# Epoch 51: Cost = 0.4418 Weights = [[1.07575637 0.68560163]
#  [2.39461545 1.15422177]
#  [0.61783984 2.82283908]]
# Epoch 61: Cost = 0.4331 Weights = [[1.13463079 0.59684448]
#  [2.31145471 1.20130972]
#  [0.631065   2.82283908]]
# Epoch 71: Cost = 0.4274 Weights = [[1.18111091 0.50546868]
#  [2.23906113 1.22194684]
#  [0.64250929 2.82283908]]
# Epoch 81: Cost = 0.4230 Weights = [[1.21970799 0.41925932]
#  [2.17342888 1.22013906]
#  [0.65432834 2.82283908]]
# Epoch 91: Cost = 0.4188 Weights = [[1.2534363  0.33973892]
#  [2.11150899 1.19933363]
#  [0.66841293 2.82283908]]
# Epoch 100: Cost = 0.4147 Weights = [[1.28115098 0.27408997]
#  [2.05716995 1.16675717]
#  [0.68413891 2.82283908]]

# %% [markdown]
# ## Lebkuchen

# %%
opt = qml.AdamOptimizer(stepsize=0.01)

num_qubits = 4
dev = qml.device("default.qubit", wires=num_qubits)
qml_circuit = make_qml_circuit(dev)

encoding_fn = density_matrix_encoding
entanglement_fn = full_entanglement 

X = X_train[lebkuchen]
Y = y_train[lebkuchen]


for reuploading_count in (1, 3):
    weights = qnp.array(
        np.random.uniform(0, math.pi, size=(reuploading_count, num_qubits)), 
        requires_grad=True
    )
    
    param = [X, Y, qml_circuit, encoding_fn, entanglement_fn, reuploading_count]

    for epoch in range(100):
        args, current_cost = opt.step_and_cost(cost, weights, param)
        weights = args[0]
        if epoch % 10 == 0 or epoch == 99: 
            print(f"Epoch {epoch + 1}: Cost = {current_cost:.4f} Weights = {weights}")
# Out:
# ---------------------------------------------------------------------------
# DecompositionUndefinedError               Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pennylane\devices\preprocess.py:418, in decompose(tape, stopping_condition, stopping_condition_shots, skip_initial_state_prep, decomposer, device_wires, target_gates, name, error)
#     417 try:
# --> 418     new_ops = [
#     419         final_op
#     420         for op in tape.operations[len(prep_op) :]
#     421         for final_op in _operator_decomposition_gen(
#     422             op,
#     423             stopping_condition,
#     424             max_work_wires=num_available_work_wires,
#     425             graph_solution=graph_solution,
#     426             custom_decomposer=decomposer,
#     427             strict=True,
#     428         )
#     429     ]
#     430 except RecursionError as e:
#
# File ~\anaconda3\Lib\site-packages\pennylane\transforms\decompose.py:877, in _operator_decomposition_gen(op, acceptance_function, max_expansion, current_depth, max_work_wires, graph_solution, custom_decomposer, strict)
#     876 elif strict:
# --> 877     raise DecompositionUndefinedError(
#     878         f"Operator {op} not supported and does not provide a decomposition."
#     879     )
#     881 else:
#
# DecompositionUndefinedError: Operator QubitDensityMatrix(array([[0.00170019, 0.04119832],
#        [0.04119832, 0.99829981]]), wires=[0, 1, 2, 3]) not supported and does not provide a decomposition.
#
# The above exception was the direct cause of the following exception:
#
# DeviceError                               Traceback (most recent call last)
# Cell In[19], line 23
#      20 param = [X, Y, qml_circuit, encoding_fn, entanglement_fn, reuploading_count]
#      22 for epoch in range(100):
# ---> 23     args, current_cost = opt.step_and_cost(cost, weights, param)
#      24     weights = args[0]
#      25     if epoch % 10 == 0 or epoch == 99:
#
# File ~\anaconda3\Lib\site-packages\pennylane\optimize\gradient_descent.py:64, in GradientDescentOptimizer.step_and_cost(self, objective_fn, grad_fn, *args, **kwargs)
#      44 def step_and_cost(self, objective_fn, *args, grad_fn=None, **kwargs):
#      45     """Update trainable arguments with one step of the optimizer and return the corresponding
#      46     objective function value prior to the step.
#      47
#    (...)
#      61         If single arg is provided, list [array] is replaced by array.
#      62     """
# ---> 64     g, forward = self.compute_grad(objective_fn, args, kwargs, grad_fn=grad_fn)
#      65     new_args = self.apply_grad(g, args)
#      67     if forward is None:
#
# File ~\anaconda3\Lib\site-packages\pennylane\optimize\gradient_descent.py:122, in GradientDescentOptimizer.compute_grad(objective_fn, args, kwargs, grad_fn)
#     104 r"""Compute the gradient of the objective function at the given point and return it along with
#     105 the objective function forward pass (if available).
#     106
#    (...)
#     119     will not be evaluated and instead ``None`` will be returned.
#     120 """
#     121 g = get_gradient(objective_fn) if grad_fn is None else grad_fn
# --> 122 grad = g(*args, **kwargs)
#     123 forward = getattr(g, "forward", None)
#     125 num_trainable_args = sum(getattr(arg, "requires_grad", False) for arg in args)
#
# File ~\anaconda3\Lib\site-packages\pennylane\_grad.py:318, in grad.__call__(self, *args, **kwargs)
#     315     self._forward = self._fun(*args, **kwargs)
#     316     return ()
# --> 318 grad_value, ans = grad_fn(*args, **kwargs)  # pylint: disable=not-callable
#     319 self._forward = ans
#     321 return grad_value
#
# File ~\anaconda3\Lib\site-packages\autograd\wrap_util.py:23, in unary_to_nary.<locals>.nary_operator.<locals>.nary_f(*args, **kwargs)
#      21 else:
#      22     x = tuple(args[i] for i in argnum)
# ---> 23 return unary_operator(unary_f, x, *nary_op_args, **nary_op_kwargs)
#
# File ~\anaconda3\Lib\site-packages\pennylane\_grad.py:336, in grad._grad_with_forward(fun, x)
#     330 @staticmethod
#     331 @unary_to_nary
#     332 def _grad_with_forward(fun, x):
#     333     """This function is a replica of ``autograd.grad``, with the only
#     334     difference being that it returns both the gradient *and* the forward pass
#     335     value."""
# --> 336     vjp, ans = _make_vjp(fun, x)  # pylint: disable=redefined-outer-name
#     338     if vspace(ans).size != 1:
#     339         raise TypeError(
#     340             "Grad only applies to real scalar-output functions. "
#     341             "Try jacobian, elementwise_grad or holomorphic_grad."
#     342         )
#
# File ~\anaconda3\Lib\site-packages\autograd\core.py:12, in make_vjp(fun, x)
#      10 def make_vjp(fun, x):
#      11     start_node = VJPNode.new_root()
# ---> 12     end_value, end_node = trace(start_node, fun, x)
#      13     if end_node is None:
#      15         def vjp(g):
#
# File ~\anaconda3\Lib\site-packages\autograd\tracer.py:12, in trace(start_node, fun, x)
#      10 with trace_stack.new_trace() as t:
#      11     start_box = new_box(x, t, start_node)
# ---> 12     end_box = fun(start_box)
#      13     if isbox(end_box) and end_box._trace == start_box._trace:
#      14         return end_box._value, end_box._node
#
# File ~\anaconda3\Lib\site-packages\autograd\wrap_util.py:17, in unary_to_nary.<locals>.nary_operator.<locals>.nary_f.<locals>.unary_f(x)
#      15 else:
#      16     subargs = subvals(args, zip(argnum, x))
# ---> 17 return fun(*subargs, **kwargs)
#
# Cell In[16], line 4, in cost(weights, param)
#       1 def cost(weights, param):
#       2     [X, Y, qml_circuit, encoding_fn, entanglement_fn, reuploading_count] = param
#       3     predictions = qnp.array([
# ----> 4         (qml_circuit(weights, x, encoding_fn, entanglement_fn, reuploading_count) * 0.5 + 1)
#       5         for x in X
#       6     ])
#       7     return qnp.mean((predictions - Y) ** 2)
#
# File ~\anaconda3\Lib\site-packages\pennylane\workflow\qnode.py:895, in QNode.__call__(self, *args, **kwargs)
#     892     from ._capture_qnode import capture_qnode  # pylint: disable=import-outside-toplevel
#     894     return capture_qnode(self, *args, **kwargs)
# --> 895 return self._impl_call(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pennylane\workflow\qnode.py:868, in QNode._impl_call(self, *args, **kwargs)
#     865 # Calculate the classical jacobians if necessary
#     866 self._transform_program.set_classical_component(self, args, kwargs)
# --> 868 res = execute(
#     869     (tape,),
#     870     device=self.device,
#     871     diff_method=self.diff_method,
#     872     interface=self.interface,
#     873     transform_program=self._transform_program,
#     874     gradient_kwargs=self.gradient_kwargs,
#     875     **self.execute_kwargs,
#     876 )
#     877 res = res[0]
#     879 # convert result to the interface in case the qfunc has no parameters
#
# File ~\anaconda3\Lib\site-packages\pennylane\workflow\execution.py:234, in execute(tapes, device, diff_method, interface, grad_on_execution, cache, cachesize, max_diff, device_vjp, postselect_mode, mcm_method, gradient_kwargs, transform_program, executor_backend)
#     231 outer_transform, inner_transform = _setup_transform_program(device, config, cache, cachesize)
#     233 #### Executing the configured setup #####
# --> 234 tapes, outer_post_processing = outer_transform(tapes)
#     236 assert not outer_transform.is_informative, "should only contain device preprocessing"
#     238 results = run(tapes, device, config, inner_transform)
#
# File ~\anaconda3\Lib\site-packages\pennylane\transforms\core\transform_program.py:496, in TransformProgram.__call__(self, *args, **kwargs)
#     494 if type(args[0]).__name__ == "Jaxpr":
#     495     return self.__call_jaxpr(*args, **kwargs)
# --> 496 return self.__call_tapes(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pennylane\transforms\core\transform_program.py:426, in TransformProgram.__call_tapes(self, tapes)
#     424 if argnums is not None:
#     425     tape.trainable_params = argnums[tape_idx]
# --> 426 new_tapes, fn = transform(tape, *targs, **tkwargs)
#     427 execution_tapes.extend(new_tapes)
#     429 fns.append(fn)
#
# File ~\anaconda3\Lib\site-packages\pennylane\devices\preprocess.py:438, in decompose(tape, stopping_condition, stopping_condition_shots, skip_initial_state_prep, decomposer, device_wires, target_gates, name, error)
#     436 except DecompositionUndefinedError as e:
#     437     message = str(e).replace("not supported", f"not supported with {name}")
# --> 438     raise error(message) from e
#     440 tape = tape.copy(operations=prep_op + new_ops)
#     442 return (tape,), null_postprocessing
#
# DeviceError: Operator QubitDensityMatrix(array([[0.00170019, 0.04119832],
#        [0.04119832, 0.99829981]]), wires=[0, 1, 2, 3]) not supported with default.qubit and does not provide a decomposition.
